# %%
import google.generativeai as genai
from google.generativeai import GenerativeModel
from dotenv import load_dotenv
import os
import json
from pypdf import PdfReader
from langchain.text_splitter import RecursiveCharacterTextSplitter # División de texto
from elasticsearch import Elasticsearch
import ollama
from gpt4all import GPT4All

# %%
def get_gemini_client():
    load_dotenv()
    api_key = os.getenv("GEMINI_API_KEY")
    genai.configure(api_key=api_key)

# %%
def get_embedding(text, model="models/embedding-001"):
    """Get embedding for a single piece of text"""
    result = genai.embed_content(
        model=model,
        content=text,
        task_type="retrieval_document"  # or "retrieval_query", "classification", etc.
    )
    return result['embedding']

# %%
def get_json_context(path_schema):
    #read schema
    with open(path_schema, 'r', encoding='utf-8') as f:
        context_data = json.load(f)
        context_str = json.dumps(context_data) #convert to string well formatted
        context_str = "**JSON SCHEMA TO FOLLOW:**\n" + context_str
    return context_str

# %%
def chunk_text(texto):
    splitter = RecursiveCharacterTextSplitter(
        chunk_size=400,
        chunk_overlap=50,
        separators=["\n\n", "\n", ".", " ", ""]
    )
    chunks = splitter.split_text(texto)
    return chunks

# %%
def process_chunks(filename):
    #leemos schema
    with open('../../JSONS/baseSchema.json', 'r', encoding='utf-8') as f:
        json_schema = json.load(f)
    
    #leemos prompt para el LLM (inicial)
    with open('jsonFillPrompt.txt', 'r', encoding='utf-8') as f:
        initial_instructions = f.read()
    
    #leemos prompt de refinamiento
    with open('jsonRefinePrompt.txt', 'r', encoding='utf-8') as f:
        refine_instructions = f.read()

    #leemos documento legal
    reader = PdfReader('../../Documentos/CODIGO PENAL DE LA NACION ARGENTINA.pdf')
    legal_doc = ""
    for page in reader.pages:
        legal_doc += page.extract_text() + "\n"
    
    # Leer documento legal desde un archivo .txt
    '''
    with open(f'./examples/{filename}.txt', 'r', encoding='utf-8') as f:
        legal_doc = f.read()
    '''

    # Dividir en chunks
    legal_doc_chunks = chunk_text(legal_doc)
    print(f"Total de chunks: {len(legal_doc_chunks)}")
    
    # Limitar a 8 chunks
    legal_doc_chunks = legal_doc_chunks[:2]
    print(f"Procesando solo los primeros {len(legal_doc_chunks)} chunks")

    print(legal_doc_chunks[0])

    # PASO 1: Crear JSON inicial con el primer chunk + schema completo
    first_chunk_prompt = (
        initial_instructions +
        "\n\n**JSON SCHEMA:**\n" +
        json.dumps(json_schema, indent=2) +
        "\n\n**DOCUMENT:**\n" +
        legal_doc_chunks[0]
    )
    
    refined_json_dict = {}
    
    # opcion gemini
    print("Procesando chunk 1...")
    model = GenerativeModel("gemini-2.0-flash-lite")
    response = model.generate_content(first_chunk_prompt)
    
    '''
    response = ollama.chat(
        model="phi3",  # or "mistral", "phi3", etc. (depends on what’s installed locally)
        messages=[{"role": "user", "content": first_chunk_prompt}]
    )
    '''
    
    '''model = GPT4All(
        model_name="DeepSeek-R1-Distill-Qwen-14B-Q4_0.gguf",
        device="gpu"
    )'''

    print(response.text)
    
    # Parsear respuesta inicial
    try:
        refined_json_dict = json.loads(response.text)
    except json.JSONDecodeError:
        # If model added extra text, extract JSON portion
        import re
        match = re.search(r'\{.*\}', response.text, re.DOTALL)
        if match:
            refined_json_dict = json.loads(match.group(0))
        else:
            raise ValueError("First chunk did not return valid JSON")
    
    # print("JSON inicial creado: ", response.text)
    # PASO 2: Refinar con chunks restantes (SIN enviar el schema completo)
    for i, chunk in enumerate(legal_doc_chunks[1:], start=2):
        print(f"Procesando chunk {i}/{len(legal_doc_chunks)}...")
        
        # Prompt simplificado: instrucciones + JSON actual + nuevo chunk
        refine_prompt = (
            refine_instructions +
            "\n\n**EXISTING JSON:**\n" +
            json.dumps(refined_json_dict, ensure_ascii=False) +
            "\n\n**NEW CHUNK:**\n" +
            chunk
        )
        
        '''
        response = ollama.chat(
            model="phi3",  # or "mistral", "phi3", etc. (depends on what’s installed locally)
            messages=[{"role": "user", "content": refine_prompt}]
        )
        '''
        
        response = model.generate_content(refine_prompt)
        # Actualizar JSON refinado
        # refined_json = response.text
        
        # Parse JSON safely
        try:
            refined_json_dict = json.loads(response.text)
        except json.JSONDecodeError:
            match = re.search(r'\{.*\}', response.text, re.DOTALL)
            if match:
                refined_json_dict = json.loads(match.group(0))
            else:
                print(f"Warning: Chunk {i} returned invalid JSON, skipping update")
                
    # Guardar resultado final
    print("Guardando resultado...")
    with open(f'./examples_processed/{filename}.json', 'w', encoding='utf-8') as f:
        json.dump(refined_json_dict, f, ensure_ascii=False, indent=2)
                
    return refined_json_dict

# %%
''' DELETE INDEX

import json
from elasticsearch import Elasticsearch
es = Elasticsearch("http://localhost:9200")

index_name = "lawai_legal_docs"

es.indices.delete(index=index_name, ignore=[400, 404])

with open("../elasticSearch/lawai_mapping.json") as f:
    mapping = json.load(f)["mapping"]

# es.indices.create(index="lawai", mappings=mapping)
'''
# Out:
# ' DELETE INDEX\n\nimport json\nfrom elasticsearch import Elasticsearch\nes = Elasticsearch("http://localhost:9200")\n\nindex_name = "lawai_legal_docs"\n\nes.indices.delete(index=index_name, ignore=[400, 404])\n\nwith open("../elasticSearch/lawai_mapping.json") as f:\n    mapping = json.load(f)["mapping"]\n\n# es.indices.create(index="lawai", mappings=mapping)\n'

# %%
def get_embedding_ollama(text: str, model="nomic-embed-text"):
    response = ollama.embeddings(model=model, prompt=text)
    return response["embedding"]

# %%
#main
if __name__ == "__main__":
    get_gemini_client()
    
    filename = 'example_1'
    
    # refined_json_dict = process_chunks(filename)
    with open(f'./examples_processed/{filename}.json', "r", encoding="utf-8") as f:
        refined_json_dict = json.load(f)
       
    # Elastic Search: define index
    with open('../elasticSearch/lawai_mapping.json') as f:
        lawai_mapping = json.load(f)  
    
    es = Elasticsearch("http://localhost:9200")

    index_name = "lawai_legal_docs"
    
    if not es.indices.exists(index=index_name):
        es.indices.create(index=index_name, body=lawai_mapping["mapping"])
        print(f"Index '{index_name}' created successfully!")
    else:
        print("Index already exists.")
    

    # refined_json_dict = json.loads(refined_json)
    
    # generate embeddings for the full text
    
    '''
    full_text = refined_json_dict["content"]["full_text"]
    # embedding = get_embedding(full_text)
    embedding = ollama.embeddings(model="nomic-embed-text", prompt=full_text)["embedding"]

    # 3. store in JSON
    refined_json_dict.setdefault("analysis", {})
    refined_json_dict["analysis"]["embeddings"] = embedding
    
    # Index (insert) the document
    es.index(
        index=index_name, 
        id=refined_json_dict["document_id"], 
        document=refined_json_dict
    )
    print("Document indexed successfully!")
    # print("¡Proceso completado!: \n"+ refined_json_dict)
    
    '''

    # Query
    query = {
        "query": {
            "match": {
                    "search_fields.searchable_text": "robo"
                }
            }
        }

    results = es.search(index=index_name, body=query)
    print(results)
    
    query_text = "penas y condenación condicional en el código penal"

    query_embedding = ollama.embeddings(model="nomic-embed-text", prompt=query_text)["embedding"]

    res = es.search(
        index="lawai_legal_docs",
        knn={
            "field": "analysis.embeddings",
            "query_vector": query_embedding,
            "k": 5,
            "num_candidates": 50
        },
        _source=["document_id", "search_fields.searchable_text"]
    )
    
    print(res)
    
    for hit in results["hits"]["hits"]:
        print(hit["_source"]["metadata"]["title"])
# Out:
# Index already exists.
# {'took': 2, 'timed_out': False, '_shards': {'total': 1, 'successful': 1, 'skipped': 0, 'failed': 0}, 'hits': {'total': {'value': 1, 'relation': 'eq'}, 'max_score': 0.84424853, 'hits': [{'_index': 'lawai_legal_docs', '_id': 'doc-12345', '_score': 0.84424853, '_source': {'document_id': 'doc-12345', 'metadata': {'title': 'Contestación de Demanda - Ratificación de Despido por Robo y Pérdida de Confianza', 'source': 'Juzgado de Trabajo Número 5', 'url': None, 'document_type': 'auto', 'status': 'vigente', 'validity_dates': {'start_date': '2023-10-27', 'end_date': None, 'promulgation_date': '2023-10-27'}, 'jurisdiction': 'provincial', 'legal_area': ['laboral']}, 'content': {'full_text': 'En respuesta a la demanda presentada, se ratifica el despido justificado del empleado debido al robo y la consecuente pérdida de confianza. CONTESTA DEMANDA. OFRECE PRUEBA Señor Juez: _, abogada (Tº_- Fº_ constituyendo domicilio en _ y domicilio electrónico en _, en autos “_ c/ _ s/ despido” (Exp. Nº _) a V.S. digo: I.- PERSONERÍA Que, como lo acredito con la copia de poder general que se acompaña -la que, según declaro bajo juramento, es fiel a su original vigente- soy mandataria judicial de _ (CUIT _), con domicilio en _.', 'structured_sections': []}, 'extracted_entities': {'laws_cited': [], 'articles': [], 'decrees_cited': [], 'resolutions_cited': [], 'treaties_cited': [], 'constitutions_cited': [], 'regulations_cited': [], 'case_numbers': [], 'judges': [], 'courts': ['Juzgado de Trabajo Número 5'], 'previous_rulings': [], 'judicial_chambers': [], 'case_parties': {'actor': None, 'demandado': None}, 'lawyers': [], 'prosecutors': [], 'witnesses': [], 'document_references': [], 'keywords': ['despido', 'robo', 'pérdida de confianza']}, 'relationships': {'modifies': [], 'modified_by': [], 'derogates': [], 'derogated_by': None, 'complements': [], 'parent_law': None, 'regulations': [], 'related_cases': []}, 'analysis': {'summary': 'El documento resume la contestación a una demanda, confirmando el despido justificado de un empleado debido a un robo y la pérdida de confianza.', 'main_topics': ['despido justificado', 'robo', 'pérdida de confianza'], 'legal_precedents': [], 'doctrine_cited': [], 'embeddings': [0.7205799221992493, 0.5014031529426575, -2.3917269706726074, 0.6251828074455261, 0.17015640437602997, -1.0893778800964355, -0.6103273630142212, -1.1762841939926147, -0.8504900336265564, 0.5514913201332092, 0.039988622069358826, -0.3097645342350006, 1.294753909111023, -0.7573286890983582, 0.906498908996582, 0.13597372174263, 0.16389332711696625, -1.3534314632415771, -1.1631674766540527, 1.2677241563796997, -0.20480555295944214, -0.5876091718673706, -1.6297907829284668, 0.17458391189575195, 1.3945555686950684, 0.6005299091339111, 1.1975113153457642, 0.8418742418289185, -0.0018326108111068606, -0.06354358792304993, -0.8121922016143799, 0.7577296495437622, 0.5798400640487671, -0.0770559087395668, -0.40778848528862, -0.8070955872535706, 1.5848370790481567, 0.49654674530029297, -0.4133519232273102, -0.12245743721723557, 0.23960144817829132, -0.5126609206199646, -0.7645195722579956, -0.563273549079895, 0.6695687174797058, 0.5098888278007507, 0.41922953724861145, 0.3424968421459198, 0.7311193346977234, -1.0321072340011597, 0.3140854835510254, 0.014411943964660168, -0.11897589266300201, -1.1097732782363892, 1.173711895942688, -0.04763640835881233, -0.5453537702560425, -0.20702065527439117, -0.7600928544998169, -1.0637718439102173, 1.1729673147201538, 0.9829413294792175, -0.22295306622982025, 2.1580095291137695, 0.12141145765781403, 0.20650161802768707, -1.2375311851501465, 0.5104163885116577, -0.13178406655788422, -0.9572483897209167, 0.898195207118988, 0.22174938023090363, -0.1727275252342224, -0.11777569353580475, -0.7974399924278259, -0.581865668296814, -1.1963152885437012, -0.8231002688407898, -0.3656187057495117, -0.13930943608283997, 0.01693876087665558, -0.43881770968437195, 1.9661121368408203, -0.9439959526062012, 0.028610622510313988, -0.08202108740806 ...
# {'took': 3, 'timed_out': False, '_shards': {'total': 1, 'successful': 1, 'skipped': 0, 'failed': 0}, 'hits': {'total': {'value': 2, 'relation': 'eq'}, 'max_score': 0.8712826, 'hits': [{'_index': 'lawai_legal_docs', '_id': 'CPN-ARG-11179', '_score': 0.8712826, '_source': {'document_id': 'CPN-ARG-11179', 'search_fields': {'searchable_text': 'cÃ³digo penal naciÃ³n argentina ley 11179 disposiciones generales aplicaciÃ³n ley penal penas condenaciÃ³n condicional reparaciÃ³n perjuicios imputabilidad tentativa'}}}, {'_index': 'lawai_legal_docs', '_id': 'doc-12345', '_score': 0.814132, '_source': {'document_id': 'doc-12345', 'search_fields': {'searchable_text': 'contestacion demanda ratifica despido robo perdida confianza juzgado trabajo'}}}]}}
# Contestación de Demanda - Ratificación de Despido por Robo y Pérdida de Confianza

# %%
'''
import google.generativeai as genai

load_dotenv()
api_key = os.getenv("GEMINI_API_KEY")
genai.configure(api_key=api_key)
models = genai.list_models()
for m in models:
    print(m.name, m.supported_generation_methods)
'''
# Out:
# '\nimport google.generativeai as genai\n\nload_dotenv()\napi_key = os.getenv("GEMINI_API_KEY")\ngenai.configure(api_key=api_key)\nmodels = genai.list_models()\nfor m in models:\n    print(m.name, m.supported_generation_methods)\n'
